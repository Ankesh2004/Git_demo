# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankesh2004/Git_demo/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Import Required Libraries

# %%
import os
import cv2
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import layers, optimizers
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input, Dense, Flatten, Dropout, AveragePooling2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Data Preparation

# %%
# Define dataset directory
X_Ray_Directory = '/content/drive/My Drive/DL_Dataset/train'
test_directory = '/content/drive/My Drive/DL_Dataset/test'

# Image preprocessing and augmentation
image_generator = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Load training and validation data
train_generator = image_generator.flow_from_directory(
    directory=X_Ray_Directory,
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = image_generator.flow_from_directory(
    directory=X_Ray_Directory,
    target_size=(224, 224),
    batch_size=40,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)

# Print class indices
print("Class indices:", train_generator.class_indices)

# Define label names
label_names = {
    0: 'Bacterial_Pneumonia',
    1: 'Covid-19',
    2: 'Normal',
    3: 'Viral_Pneumonia'
}
# Out:
# Found 5893 images belonging to 4 classes.
# Found 1471 images belonging to 4 classes.
# Class indices: {'Bacterial_Pneumonia': 0, 'Covid-19': 1, 'Normal': 2, 'Viral_Pneumonia': 3}

# %% [markdown]
# 3. Visualize Sample Images

# %%
import matplotlib.pyplot as plt
import numpy as np

# Number of classes and images per class to display
num_classes = len(label_names)
images_per_class = 5

# Prepare figure grid
fig, axes = plt.subplots(num_classes, images_per_class + 1, figsize=(15, 10))

# Get a fresh batch of images and labels
train_images, train_labels = next(train_generator)

# Plot each class row
for class_idx in range(num_classes):
    # First column: display the class name as text
    axes[class_idx, 0].text(0.5, 0.5, label_names[class_idx],
                            fontsize=12, ha='center', va='center')
    axes[class_idx, 0].axis('off')

    # Get images that belong to this class
    class_images = train_images[np.argmax(train_labels, axis=1) == class_idx]

    for img_idx in range(images_per_class):
        if img_idx < len(class_images):
            axes[class_idx, img_idx + 1].imshow(class_images[img_idx])
            axes[class_idx, img_idx + 1].axis('off')
        else:
            axes[class_idx, img_idx + 1].axis('off')  # Hide if not enough samples

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Load Pretrained Model (ResNet50)

# %%
# Load ResNet50 model without top layers
basemodel = ResNet50(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# Freeze early layers for transfer learning
for layer in basemodel.layers[:-10]:
    layer.trainable = False
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %% [markdown]
# 5. Build Custom Model Head

# %%
from tensorflow.keras.optimizers import Adam

# Define custom layers on top of ResNet50
headmodel = basemodel.output
headmodel = AveragePooling2D(pool_size=(4, 4))(headmodel)
headmodel = Flatten(name='flatten')(headmodel)
headmodel = Dense(256, activation='relu')(headmodel)
headmodel = Dropout(0.3)(headmodel)
headmodel = Dense(128, activation='relu')(headmodel)
headmodel = Dropout(0.2)(headmodel)
headmodel = Dense(4, activation='softmax')(headmodel)

# Create the final model
model = Model(inputs=basemodel.input, outputs=headmodel)

# Compile model with Adam optimizer
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=1e-4),
    metrics=['accuracy']
)

# %% [markdown]
# 6. Train the Model

# %%
# Define callbacks
earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=20, verbose=1)
checkpointer = ModelCheckpoint(filepath='best_model.keras', save_best_only=True, verbose=1)

# Train model
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[checkpointer, earlystopping]
)
# Out:
# Epoch 1/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7687 - loss: 0.5676
# Epoch 1: val_loss improved from inf to 1.94250, saving model to best_model.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.7688 - loss: 0.5675 - val_accuracy: 0.4765 - val_loss: 1.9425
# Epoch 2/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7767 - loss: 0.5574
# Epoch 2: val_loss did not improve from 1.94250
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.7767 - loss: 0.5574 - val_accuracy: 0.2842 - val_loss: 2.7955
# Epoch 3/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7767 - loss: 0.5434
# Epoch 3: val_loss did not improve from 1.94250
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - accuracy: 0.7767 - loss: 0.5434 - val_accuracy: 0.1788 - val_loss: 7.2903
# Epoch 4/50
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7878 - loss: 0.5400
# Epoch 4: val_loss improved from 1.94250 to 0.75298, saving model to best_model.keras
# ...

# %% [markdown]
# 7. Evaluate Model Performance

# %%
# Plot Training & Validation Accuracy/Loss
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_title('Model Accuracy')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Accuracy')
axs[0].legend()

axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Model Loss')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].legend()

plt.show()

# %% [markdown]
# 8. Save the Model

# %%
model.save('/content/drive/My Drive/my_model.keras')

# %% [markdown]
# 9. Test Model on Unseen Data

# %%
# Load test dataset
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_directory(
    directory=test_directory,
    target_size=(256, 256),
    batch_size=40,
    class_mode='categorical',
    shuffle=True
)

# Evaluate model on test data
evaluate = model.evaluate(test_generator, verbose=1)
print(f"Test Accuracy: {evaluate[1]:.4f}")
# Out:
# Found 1844 images belonging to 4 classes.
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 580s 12s/step - accuracy: 0.7262 - loss: 0.7964
# Test Accuracy: 0.7153

# %% [markdown]
# 10. Generate Predictions & Confusion Matrix

# %%
# Reverse label names mapping for predictions
label_map = {v: k for k, v in label_names.items()}

predictions, originals = [], []

for class_name in os.listdir(test_directory):
    class_dir = os.path.join(test_directory, class_name)
    if not os.path.isdir(class_dir):
        continue

    label = label_map.get(class_name, -1)
    if label == -1:
        print(f"Unknown class: {class_name}")
        continue

    for img_name in os.listdir(class_dir):
        img_path = os.path.join(class_dir, img_name)
        img = cv2.imread(img_path)
        img = cv2.resize(img, (256, 256)) / 255.0
        img = img.reshape(1, 256, 256, 3)

        pred = np.argmax(model.predict(img))
        predictions.append(pred)
        originals.append(label)

# Calculate Accuracy, Confusion Matrix, and Classification Report
accuracy = accuracy_score(originals, predictions)
conf_matrix = confusion_matrix(originals, predictions)
class_report = classification_report(originals, predictions, target_names=label_names.values())

print(f"Test Accuracy: {accuracy:.4f}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# Display Confusion Matrix as Heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt='d',
            xticklabels=label_names.values(),
            yticklabels=label_names.values())
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(1, 256, 256, 3))
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ...

# %% [markdown]
# 11. Display Sample Predictions

# %%
import random

# Reverse label_names dictionary to map index -> label
label_names = {
    0: 'Bacterial_Pneumonia',
    1: 'Covid-19',
    2: 'Normal',
    3: 'Viral_Pneumonia'
}

# Collect all image file paths from test set
test_image_paths = []
for class_name in os.listdir(test_directory):
    class_path = os.path.join(test_directory, class_name)
    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            test_image_paths.append(os.path.join(class_path, img_name))

# Shuffle and pick L*W samples for display
sample_indices = random.sample(range(len(test_image_paths)), L * W)

# Plotting predictions vs actuals
L, W = 5, 5
fig, axes = plt.subplots(L, W, figsize=(12, 12))
axes = axes.ravel()

for idx, ax in zip(sample_indices, axes):
    img_path = test_image_paths[idx]
    img = cv2.imread(img_path)
    if img is None:
        continue  # Skip if image failed to load

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(img)
    ax.set_title(f"Pred: {label_names[predictions[idx]]}\nTrue: {label_names[originals[idx]]}")
    ax.axis("off")

plt.tight_layout()
plt.show()
